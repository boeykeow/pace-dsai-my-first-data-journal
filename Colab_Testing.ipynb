# %% [markdown]
# <a href="https://colab.research.google.com/github/boeykeow/pace-dsai-my-first-data-journal/blob/main/Colab_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Try Google Colab!")
# Out:
# Try Google Colab!

# %%
print("This is to make change with 2nd print")
# Out:
# This is to make change with 2nd print
